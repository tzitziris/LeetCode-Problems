# %%
print("test file")
# Out:
# test file

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        self.child = None
        self.parent = None
        self.sibling = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 1
