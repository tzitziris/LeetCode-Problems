# %%
import json

# Replace 'path_to_your_notebook.ipynb' with the path to your notebook file
notebook_path = '/Users/sophianostzitzires/python notebooks/LeetCode-Problems/Linked-Lists/test2.ipynb'

try:
    with open(notebook_path, 'r', encoding='utf-8') as f:
        json.load(f)
    print("The notebook is valid JSON.")
except json.JSONDecodeError as e:
    print(f"Invalid JSON: {e}")
# Out:
# Invalid JSON: Expecting value: line 1 column 1 (char 0)
